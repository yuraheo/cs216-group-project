# %%
# Run this code cell to import relevant libraries

import numpy as np
import pandas as pd
import seaborn as sns

# %%
childcare_costs = pd.read_csv("childcare_costs.csv")
childcare_costs.head()
# Out:
#    county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0              1001        2008    5.42     4.41     6.32         4.6
# 1              1001        2009    5.93     5.72     6.11         4.8
# 2              1001        2010    6.21     5.57     6.78         5.1
# 3              1001        2011    7.55     8.13     7.03         6.2
# 4              1001        2012    8.60     8.88     8.29         6.7
#
#    funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  memp_p  \
# 0          3.5          5.6          68.9                 66.9  ...   21.55
# 1          4.6          5.0          70.8                 63.7  ...   21.96
# 2          4.6          5.6          71.3                 67.0  ...   21.28
# 3          6.3          6.1          70.2                 66.5  ...   22.80
# 4          6.4          7.0          70.6                 67.1  ...   22.88
#
#    femp_p   mcsa  mfccsa  mc_infant  mc_toddler  mc_preschool  mfcc_infant  \
# ...

# %%
counties = pd.read_csv("counties.csv")
counties.head()
# Out:
#    county_fips_code     county_name state_name state_abbreviation
# 0              1001  Autauga County    Alabama                 AL
# 1              1003  Baldwin County    Alabama                 AL
# 2              1005  Barbour County    Alabama                 AL
# 3              1007     Bibb County    Alabama                 AL
# 4              1009   Blount County    Alabama                 AL

# %%
df = childcare_costs.merge(counties, how = 'left', on = "county_fips_code")
df.head()
# Out:
#    county_fips_code  study_year  unr_16  funr_16  munr_16  unr_20to64  \
# 0              1001        2008    5.42     4.41     6.32         4.6
# 1              1001        2009    5.93     5.72     6.11         4.8
# 2              1001        2010    6.21     5.57     6.78         5.1
# 3              1001        2011    7.55     8.13     7.03         6.2
# 4              1001        2012    8.60     8.88     8.29         6.7
#
#    funr_20to64  munr_20to64  flfpr_20to64  flfpr_20to64_under6  ...  mfccsa  \
# 0          3.5          5.6          68.9                 66.9  ...   81.40
# 1          4.6          5.0          70.8                 63.7  ...   85.68
# 2          4.6          5.6          71.3                 67.0  ...   89.96
# 3          6.3          6.1          70.2                 66.5  ...   94.25
# 4          6.4          7.0          70.6                 67.1  ...   98.53
#
#    mc_infant  mc_toddler  mc_preschool  mfcc_infant  mfcc_toddler  \
# ...

# %%
healthdata = pd.read_csv("healthdata.csv")
healthdata.head()

my_list = healthdata.columns
for start in range(0, len(my_list), 50):
    end = start + 50
    group = my_list[start:end]
    print(f"Group {start//50 + 1}: {group}")
# Out:
# Group 1: Index(['name', 'fips', 'state', 'land_area (km^2)', 'area (km^2)',
#        'longitude (deg)', 'latitude (deg)', 'noaa/prcp', 'noaa/snow',
#        'noaa/temp', 'noaa/altitude', 'noaa/temp-jan', 'noaa/temp-apr',
#        'noaa/temp-jul', 'noaa/temp-oct', 'zip-codes',
#        'race/non_hispanic_white_alone_male',
#        'race/non_hispanic_white_alone_female', 'race/black_alone_male',
#        'race/black_alone_female', 'race/asian_alone_male',
#        'race/asian_alone_female', 'race/hispanic_male', 'race/hispanic_female',
#        'age/0-4', 'age/5-9', 'age/10-14', 'age/15-19', 'age/20-24',
#        'age/25-29', 'age/30-34', 'age/35-39', 'age/40-44', 'age/45-49',
#        'age/50-54', 'age/55-59', 'age/60-64', 'age/65-69', 'age/70-74',
#        'age/75-79', 'age/80-84', 'age/85+', 'male', 'female',
#        'population/2010', 'population/2011', 'population/2012',
#        'population/2013', 'population/2014', 'population/2015'],
#       dtype='object')
# ...

# %%
pres = pd.read_csv("countypres_2000-2020.csv")
pres.head()

pres["county_fips"] = pres["county_fips"].fillna('').astype(str).str.replace(".0","",regex=False)
pres.head()
# Out:
#    year    state state_po county_name county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA        1001  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA        1001  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA        1001  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA        1001  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN        1003  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# 2     RALPH NADER       GREEN             160       17208  20220315  TOTAL
# 3           OTHER       OTHER             113       17208  20220315  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20220315  TOTAL
